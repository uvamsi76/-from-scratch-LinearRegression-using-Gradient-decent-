# %%
import numpy as np

# %%
a=[[1,2,3,4,5]]
b=[[1,2,3,6,7]]

# %%
A=np.array(a)
B=np.array(b)
A
# Out:
# array([[1, 2, 3, 4, 5]])

# %%
A=A.reshape(5,1)
B=B.reshape(5,1)
print(A.shape,B.shape)
A
# Out:
# (5, 1) (5, 1)
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
C=np.dot(A.T,B)
print(C.item())
# Out:
# 73

# %%
num_rows = A.shape[0]

zeros_column = np.ones((num_rows, 1), dtype=A.dtype)

result_array = np.concatenate((A, zeros_column), axis=1)

print(result_array)
# Out:
# [[1 1]
#  [2 1]
#  [3 1]
#  [4 1]
#  [5 1]]

# %%
A
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
HX=np.zeros((1,1))

# %%
HX.shape
# Out:
# (1, 1)

# %%
HX
# Out:
# 1

# %%
C=[[1,2,3],[1,2,3],[1,2,3]]
C=np.array(C)
C[:,0]
# Out:
# array([1, 1, 1])

# %%
t=np.zeros((3,1))

# %%
t[0]=10

# %%
t
# Out:
# array([[10.],
#        [ 0.],
#        [ 0.]])

# %%
a=[[2.9,9.6,4.0],[1,1,1]]
a=np.array(a)

# %%
a.T
# Out:
# array([[2.9, 1. ],
#        [9.6, 1. ],
#        [4. , 1. ]])

# %%
# This code is an extension of the previous example using matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate sample data
theta = np.linspace(0, 2 * np.pi, 100)
z = np.linspace(0, 1, 100)
r = z**2 + 1

# Use seaborn to set a style
sns.set(style="whitegrid")

# Plot a 3D surface plot
ax.plot3D(r * np.cos(theta), r * np.sin(theta), z, 'b-')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()
